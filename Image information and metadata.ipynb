# %% [markdown]
# # Image information and metadata

# %%
import ee
from pprint import pprint

ee.Initialize()

# Load an image
image = ee.Image('LANDSAT/LC08/C01/T1/LC08_044034_20140318')

# Get information about the bands as a list
bandNames = image.bandNames()
pprint(bandNames.getInfo())

# Get projection information from band 1
b1proj = image.select('B1').projection()
pprint(b1proj.getInfo())

# Get scale (in meters) information from band 1
b1scale = image.select('B1').projection().nominalScale()
pprint(b1scale.getInfo())

# Note that different bands can have different projections and scale
b8scale = image.select('B8').projection().nominalScale()
pprint(b8scale.getInfo())

# Get a list of all metadata properties
# image.getInfo() return a dict object, the key 'properites' store the metadata of image
properties = image.getInfo()['properties']
pprint(properties.keys())

# Get a specific metadata property
cloudiness = image.get('CLOUD_COVER').getInfo()
print(cloudiness)

# Get the timestamp and covert it to a date
date = ee.Date(image.get('system:time_start')).getInfo()
pprint(date)
# Out:
# [u'B1',
#  u'B2',
#  u'B3',
#  u'B4',
#  u'B5',
#  u'B6',
#  u'B7',
#  u'B8',
#  u'B9',
#  u'B10',
#  u'B11',
#  u'BQA']
# {u'crs': u'EPSG:32610',
#  u'transform': [30.0, 0.0, 460785.0, 0.0, -30.0, 4264215.0],
#  u'type': u'Projection'}
# 30.0
# 15.0
# [u'THERMAL_LINES',
#  u'EARTH_SUN_DISTANCE',
#  u'SCENE_CENTER_TIME',
#  u'REQUEST_ID',
#  u'RADIANCE_MULT_BAND_7',
#  u'RADIANCE_MULT_BAND_6',
#  u'RADIANCE_MULT_BAND_5',
#  u'RADIANCE_MULT_BAND_4',
#  u'RADIANCE_MULT_BAND_3',
#  u'RADIANCE_MULT_BAND_2',
#  u'RADIANCE_MULT_BAND_1',
#  u'GEOMETRIC_RMSE_MODEL',
#  u'RADIANCE_MULT_BAND_9',
#  u'RADIANCE_MULT_BAND_8',
#  u'GROUND_CONTROL_POINTS_VERSION',
#  u'TRUNCATION_OLI',
#  u'ELLIPSOID',
#  u'RADIANCE_ADD_BAND_1',
#  u'BPF_NAME_OLI',
#  u'RADIANCE_ADD_BAND_3',
#  u'GROUND_CONTROL_POINTS_VERIFY',
#  u'RADIANCE_ADD_BAND_2',
#  u'RADIANCE_ADD_BAND_5',
#  u'system:asset_size',
#  u'REFLECTANCE_ADD_BAND_2',
#  u'RADIANCE_ADD_BAND_7',
#  u'WRS_PATH',
#  u'DATA_TYPE',
#  u'REFLECTIVE_LINES',
#  u'IMAGE_QUALITY_TIRS',
#  u'SPACECRAFT_ID',
#  u'STATION_ID',
#  u'CPF_NAME',
#  u'google:registration_ratio',
#  u'REFLECTANCE_MULT_BAND_9',
#  u'REFLECTANCE_MULT_BAND_8',
#  u'SENSOR_ID',
#  u'REFLECTANCE_MULT_BAND_1',
#  u'REFLECTANCE_MULT_BAND_3',
#  u'REFLECTANCE_MULT_BAND_2',
#  u'REFLECTANCE_MULT_BAND_5',
#  u'REFLECTANCE_MULT_BAND_4',
#  u'REFLECTANCE_MULT_BAND_7',
#  u'REFLECTANCE_MULT_BAND_6',
#  u'WRS_ROW',
#  u'CLOUD_COVER_LAND',
#  u'GEOMETRIC_RMSE_MODEL_X',
#  u'GEOMETRIC_RMSE_MODEL_Y',
#  u'THERMAL_SAMPLES',
#  u'UTM_ZONE',
#  u'SATURATION_BAND_8',
#  u'SATURATION_BAND_9',
#  u'SATURATION_BAND_2',
#  u'SATURATION_BAND_3',
#  u'GRID_CELL_SIZE_THERMAL',
#  u'SATURATION_BAND_6',
#  u'COLLECTION_NUMBER',
#  u'SATURATION_BAND_4',
#  u'SATURATION_BAND_5',
#  u'google:registration_offset_y',
#  u'google:registration_offset_x',
#  u'K2_CONSTANT_BAND_11',
#  u'K2_CONSTANT_BAND_10',
#  u'LANDSAT_SCENE_ID',
#  u'SUN_AZIMUTH',
#  u'system:time_start',
#  u'TARGET_WRS_PATH',
#  u'BPF_NAME_TIRS',
#  u'ELEVATION_SOURCE',
#  u'GEOMETRIC_RMSE_VERIFY',
#  u'GRID_CELL_SIZE_REFLECTIVE',
#  u'ORIENTATION',
#  u'RADIANCE_MULT_BAND_11',
#  u'RADIANCE_MULT_BAND_10',
#  u'PANCHROMATIC_SAMPLES',
#  u'TARGET_WRS_ROW',
#  u'PROCESSING_SOFTWARE_VERSION',
#  u'SUN_ELEVATION',
#  u'COLLECTION_CATEGORY',
#  u'TIRS_STRAY_LIGHT_CORRECTION_SOURCE',
#  u'MAP_PROJECTION',
#  u'IMAGE_QUALITY_OLI',
#  u'SATURATION_BAND_1',
#  u'FILE_DATE',
#  u'RESAMPLING_OPTION',
#  u'DATE_ACQUIRED',
#  u'system:index',
#  u'PANCHROMATIC_LINES',
#  u'NADIR_OFFNADIR',
#  u'REFLECTIVE_SAMPLES',
#  u'GRID_CELL_SIZE_PANCHROMATIC',
#  u'SATURATION_BAND_7',
#  u'TIRS_SSM_POSITION_STATUS',
#  u'system:footprint',
#  u'GROUND_CONTROL_POINTS_MODEL',
#  u'TIRS_SSM_MODEL',
#  u'CLOUD_COVER',
#  u'RADIANCE_ADD_BAND_9',
#  u'RADIANCE_ADD_BAND_8',
#  u'REFLECTANCE_ADD_BAND_9',
#  u'REFLECTANCE_ADD_BAND_8',
#  u'REFLECTANCE_ADD_BAND_7',
#  u'REFLECTANCE_ADD_BAND_6',
#  u'REFLECTANCE_ADD_BAND_5',
#  u'REFLECTANCE_ADD_BAND_4',
#  u'REFLECTANCE_ADD_BAND_3',
#  u'RADIANCE_ADD_BAND_4',
#  u'REFLECTANCE_ADD_BAND_1',
#  u'RADIANCE_ADD_BAND_6',
#  u'LANDSAT_PRODUCT_ID',
#  u'K1_CONSTANT_BAND_10',
#  u'K1_CONSTANT_BAND_11',
#  u'google:registration_count',
#  u'RADIANCE_ADD_BAND_11',
#  u'RADIANCE_ADD_BAND_10',
#  u'DATUM',
#  u'RLUT_FILE_NAME',
#  u'ROLL_ANGLE']
# 0.06
# {u'type': u'Date', u'value': 1395168392050L}
